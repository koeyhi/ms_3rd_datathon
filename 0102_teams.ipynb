# %%
from google.colab import drive
drive.mount('/content/drive')

DATA_PATH = "/content/drive/MyDrive/datathon/data/"

SEED = 42
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import torch
from tqdm.auto import tqdm
import random
import os

def reset_seeds(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

# %%
df = pd.read_csv(f"{DATA_PATH}base_data_forreal.csv")
# Out:
# <ipython-input-146-2ba9eec16305>:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f"{DATA_PATH}base_data_forreal.csv")

# %%
train_tr = pd.read_csv(f"{DATA_PATH}teams_train(analyze).csv") # 학습용 승부예측 데이터
#train_target = pd.read_csv(f"{DATA_PATH}train_target_1226.csv") # 학습용 정답 데이터
test_tr = pd.read_csv(f"{DATA_PATH}teams_test(analyze).csv") # 테스트용 승부예측 데이터
#test_target = pd.read_csv(f"{DATA_PATH}test_target_1226.csv") # 테스트용 정답 데이터

# %%
train_tr.shape, test_tr.shape
# Out:
# ((10000, 156), (2334, 111))

# %% [markdown]
# # 전처리

# %%
drop_list_team = [
    "participantid",
    "playername",
    'position',
    "champion",
    "teamkills",
    "teamdeaths",
    "firstbloodkill",
    "firstbloodassist",
    "firstbloodvictim",
    "dragons (type unknown)",
    "damageshare",
    "earnedgoldshare",
    "total cs",
    "monsterkillsownjungle",
    "monsterkillsenemyjungle",
    "goldat20",
    "xpat20",
    "csat20",
    "opp_goldat20",
    "opp_xpat20",
    "opp_csat20",
    "golddiffat20",
    "xpdiffat20",
    "csdiffat20",
    "killsat20",
    "assistsat20",
    "deathsat20",
    "opp_killsat20",
    "opp_assistsat20",
    "opp_deathsat20",
    "goldat25",
    "xpat25",
    "csat25",
    "opp_goldat25",
    "opp_xpat25",
    "opp_csat25",
    "golddiffat25",
    "xpdiffat25",
    "csdiffat25",
    "killsat25",
    "assistsat25",
    "deathsat25",
    "opp_killsat25",
    "opp_assistsat25",
    "opp_deathsat25"
]

# %%
train_ft = train_tr.drop(columns=drop_list_team)
test_ft = test_tr.copy()

# %% [markdown]
# - teams

# %%
fill_zero_cols = [
    "void_grubs",
    "opp_void_grubs",
]

fill_unknown_cols = [
    "split",
    "ban1",
    "ban2",
    "ban3",
    "ban4",
    "ban5",
]

train_ft[fill_zero_cols] = train_ft[fill_zero_cols].fillna(0)
test_ft[fill_zero_cols] = test_ft[fill_zero_cols].fillna(0)

train_ft[fill_unknown_cols] = train_ft[fill_unknown_cols].fillna("unknown")
test_ft[fill_unknown_cols] = test_ft[fill_unknown_cols].fillna("unknown")

train_ft.dropna(subset=['pick1'], inplace=True)
test_ft.dropna(subset=['pick1'], inplace=True)

# %% [markdown]
# - lpl 결측치

# %%
lpl_team = [
    "Anyone's Legend",
    "Bilibili Gaming",
    "EDward Gaming",
    "FunPlus Phoenix",
    "Invictus Gaming",
    "JD Gaming",
    "LGD Gaming",
    "LNG Esports",
    "Oh My God",
    "Rare Atom",
    "Royal Never Give Up",
    "Team WE",
    "Top Esports",
    "ThunderTalk Gaming",
    "Ultra Prime",
    "Weibo Gaming",
    "Ninjas in Pyjamas"
]

# %%
missing_columns = train_ft.columns[train_ft.isnull().sum() > 0]
null_samples = train_ft[train_ft[missing_columns].isnull().any(axis=1)]

for idx, row in null_samples.iterrows():
    team_history = train_ft[
        (train_ft["teamname"] == row["teamname"])
        & (train_ft["gameid"] < row["gameid"])
    ].sort_values("gameid", ascending=False)

    for col in missing_columns:
        if pd.isnull(row[col]):
            if row["teamname"] in lpl_team:
                # LPL 팀인 경우 LCK 평균으로 채움
                lck_mean = train_ft[train_ft["league"] == "LCK"][col].mean()
                train_ft.loc[idx, col] = lck_mean
            else:
                # LPL 팀이 아닌 경우 해당 팀의 이전 5경기 평균으로 채움
                prev_5_mean = team_history[col].head(5).mean()
                if pd.notnull(prev_5_mean):
                    train_ft.loc[idx, col] = prev_5_mean
                else:
                    # 이전 5경기 데이터가 없는 경우 해당 팀의 전체 평균으로 채움
                    team_mean = train_ft[train_ft["teamname"] == row["teamname"]][col].mean()
                    train_ft.loc[idx, col] = team_mean

# %%
train_ft.isnull().sum().sum()
# Out:
# 0

# %%
missing_columns = test_ft.columns[test_ft.isnull().sum() > 0]
null_samples = test_ft[test_ft[missing_columns].isnull().any(axis=1)]

for idx, row in null_samples.iterrows():
    team_history = train_ft[
        (train_ft["teamname"] == row["teamname"])
        & (train_ft["gameid"] < row["gameid"])
    ].sort_values("gameid", ascending=False)

    for col in missing_columns:
        if pd.isnull(row[col]):
            if row["teamname"] in lpl_team:
                # LPL 팀인 경우 학습 데이터의 LCK 평균으로 채움
                lck_mean = train_ft[train_ft["league"] == "LCK"][col].mean()
                test_ft.loc[idx, col] = lck_mean
            else:
                # LPL 팀이 아닌 경우 학습 데이터에서 해당 팀의 이전 5경기 평균으로 채움
                prev_5_mean = team_history[col].head(5).mean()
                if pd.notnull(prev_5_mean):
                    test_ft.loc[idx, col] = prev_5_mean
                else:
                    # 이전 5경기 데이터가 없는 경우 학습 데이터에서 해당 팀의 전체 평균으로 채움
                    team_mean = train_ft[train_ft["teamname"] == row["teamname"]][col].mean()
                    test_ft.loc[idx, col] = team_mean

# %%
test_ft.isnull().sum().sum()
# Out:
# 0

# %%
train_ft.shape, test_ft.shape
# Out:
# ((9913, 111), (2324, 111))

# %% [markdown]
# # feature

# %% [markdown]
# - 연도별 팀순위

# %%
train_ft["date"] = pd.to_datetime(train_ft["date"])
test_ft["date"] = pd.to_datetime(test_ft["date"])

train_ft["year"] = train_ft["date"].dt.year
test_ft["year"] = test_ft["date"].dt.year

# %%
# def calculate_team_rankings(df):
#     rankings = []
#     for year in df['year'].unique():
#         for league in df['league'].unique():
#             year_league_df = df[(df['year'] == year) & (df['league'] == league)]
#             if year_league_df.empty:
#                 continue

#             # 승리 횟수를 기준으로 정렬
#             team_wins = year_league_df.groupby('teamname')['result'].sum().reset_index()
#             team_wins = team_wins.sort_values(by='result', ascending=False)

#             # 순위 부여
#             team_wins['rank'] = range(1, len(team_wins) + 1)

#             # 연도, 리그 정보 추가
#             team_wins['year'] = year
#             team_wins['league'] = league

#             rankings.append(team_wins)

#     return pd.concat(rankings)
# #result 1 = win 0 = lose

# team_rankings = calculate_team_rankings(train_ft)
# team_rankings

# %%
train_ft.shape, test_ft.shape
# Out:
# ((9913, 112), (2324, 112))

# %%
# 연도별 팀 평균kda 계산
def calculate_yearly_team_kda(df):
    # KDA 계산
    df['KDA'] = (df['kills'] + df['assists']) / df['deaths'].replace(0,1)
    df['KDA'] = df['KDA'].replace(np.inf, 0)  # 무한대 값 처리

    # 연도별 팀 평균 KDA 계산
    yearly_team_kda = df.groupby(['year', 'teamname'])['KDA'].mean().reset_index()
    return yearly_team_kda

train_year_kda = calculate_yearly_team_kda(train_ft)
test_year_kda = calculate_yearly_team_kda(test_ft)

train_year_kda
# Out:
#      year            teamname       KDA
# 0    2022         100 Thieves  7.816131
# 1    2022          AS Esports  2.209044
# 2    2022            Astralis  3.926283
# 3    2022           BNK FEARX  4.897943
# 4    2022       Beyond Gaming  8.721417
# ..    ...                 ...       ...
# 195  2024         Team Whales  5.226432
# 196  2024          V3 Esports  1.390224
# 197  2024     Vivo Keyd Stars  6.385573
# 198  2024  West Point Esports  2.028894
# 199  2024         paiN Gaming  7.162807
#
# [200 rows x 3 columns]

# %%
train_ft.shape, test_ft.shape
# Out:
# ((9913, 113), (2324, 113))

# %%
# opp_teamname

def add_opponent_teamname(df):
    df['opp_teamname'] = ''  # 빈 문자열로 초기화
    for gameid in df['gameid'].unique():
        game_data = df[df['gameid'] == gameid]
        teams = game_data['teamname'].unique()
        if len(teams) == 2:
            team1 = teams[0]
            team2 = teams[1]
            df.loc[(df['gameid'] == gameid) & (df['teamname'] == team1), 'opp_teamname'] = team2
            df.loc[(df['gameid'] == gameid) & (df['teamname'] == team2), 'opp_teamname'] = team1
    return df

train_ft = add_opponent_teamname(train_ft)
test_ft = add_opponent_teamname(test_ft)
train_ft['opp_teamname']
# Out:
# 0                           BNK FEARX
# 1                                 DRX
# 2                           BNK FEARX
# 3                                 DRX
# 4                    Kwangdong Freecs
#                     ...
# 9995                        PSG Talon
# 9996    Fukuoka SoftBank HAWKS gaming
# 9997                        PSG Talon
# 9998                        PSG Talon
# 9999    Fukuoka SoftBank HAWKS gaming
# Name: opp_teamname, Length: 9913, dtype: object

# %%
train_ft.shape, test_ft.shape
# Out:
# ((9913, 114), (2324, 114))

# %%
# 상대팀에 대한 평균 kills

def calculate_avg_kills_against_opponent(df):
    team_kills_against_opponent = {}
    for team in df['teamname'].unique():
        team_kills_against_opponent[team] = {}
        team_df = df[df['teamname'] == team]
        for opp_team in team_df['opp_teamname'].unique():
            kills_against_opp = team_df[team_df['opp_teamname'] == opp_team]['kills']
            avg_kills = kills_against_opp.mean()
            team_kills_against_opponent[team][opp_team] = avg_kills

    return team_kills_against_opponent


# 팀별 상대 팀에 대한 평균 킬 수 계산
train_avg_kills = calculate_avg_kills_against_opponent(train_ft)
test_avg_kills = calculate_avg_kills_against_opponent(test_ft)

# 결과 출력
for team, opponents in train_avg_kills.items():
    print(f"팀: {team}")
    for opponent, avg_kill in opponents.items():
        print(f"  상대 팀: {opponent}, 평균 킬: {avg_kill}")
# Out:
# 팀: DRX
#   상대 팀: BNK FEARX, 평균 킬: 10.885714285714286
#   상대 팀: Gen.G, 평균 킬: 6.875
#   상대 팀: T1, 평균 킬: 9.307692307692308
#   상대 팀: Kwangdong Freecs, 평균 킬: 12.74074074074074
#   상대 팀: OKSavingsBank Brion, 평균 킬: 11.625
#   상대 팀: Nongshim RedForce, 평균 킬: 12.884615384615385
#   상대 팀: KT Rolster, 평균 킬: 9.566666666666666
#   상대 팀: Hanwha Life Esports, 평균 킬: 9.444444444444445
#   상대 팀: Dplus KIA, 평균 킬: 7.071428571428571
#   상대 팀: Royal Never Give Up, 평균 킬: 18.0
#   상대 팀: MGN Vikings Esports, 평균 킬: 11.0
#   상대 팀: İstanbul Wildcats, 평균 킬: 26.0
#   상대 팀: Isurus, 평균 킬: 23.0
#   상대 팀: MAD Lions KOI, 평균 킬: 14.0
#   상대 팀: Rogue, 평균 킬: 15.333333333333334
#   상대 팀: Top Esports, 평균 킬: 9.0
#   상대 팀: GAM Esports, 평균 킬: 17.0
#   상대 팀: EDward Gaming, 평균 킬: 13.0
#   상대 팀: OKSavingsBank BRION, 평균 킬: 9.0
# 팀: BNK FEARX
#   상대 팀: DRX, 평균 킬: 13.2
#   상대 팀: Nongshim RedForce, 평균 킬: 11.84
#   상대 팀: Kwangdong Freecs, 평균 킬: 11.75
#   상대 팀: T1, 평균 킬: 8.91304347826087
#   상대 팀: KT Rolster, 평균 킬: 8.925925925925926
#   상대 팀: Hanwha Life Esports, 평균 킬: 12.04
#   상대 팀: Gen.G, 평균 킬: 9.615384615384615
#   상대 팀: Dplus KIA, 평균 킬: 7.36
#   상대 팀: OKSavingsBank Brion, 평균 킬: 13.5
#   상대 팀: OKSavingsBank BRION, 평균 킬: 13.88888888888889
# 팀: T1
#   상대 팀: Kwangdong Freecs, 평균 킬: 15.423076923076923
#   상대 팀: OKSavingsBank Brion, 평균 킬: 16.071428571428573
#   상대 팀: DRX, 평균 킬: 12.692307692307692
#   상대 팀: BNK FEARX, 평균 킬: 14.826086956521738
#   상대 팀: Nongshim RedForce, 평균 킬: 15.26923076923077
#   상대 팀: Dplus KIA, 평균 킬: 14.32258064516129
#   상대 팀: Hanwha Life Esports, 평균 킬: 12.307692307692308
#   상대 팀: Gen.G, 평균 킬: 11.20754716981132
#   상대 팀: KT Rolster, 평균 킬: 13.076923076923077
#   상대 팀: MGN Vikings Esports, 평균 킬: 21.0
#   상대 팀: Team Aze, 평균 킬: 22.5
#   상대 팀: DetonatioN FocusMe, 평균 킬: 22.0
#   상대 팀: G2 Esports, 평균 킬: 15.8
#   상대 팀: PSG Talon, 평균 킬: 14.5
#   상대 팀: Royal Never Give Up, 평균 킬: 12.3
#   상대 팀: Evil Geniuses, 평균 킬: 11.5
#   상대 팀: EDward Gaming, 평균 킬: 21.0
#   상대 팀: Fnatic, 평균 킬: 11.0
#   상대 팀: Cloud9, 평균 킬: 16.333333333333332
#   상대 팀: JD Gaming, 평균 킬: 14.461538461538462
#   상대 팀: MAD Lions KOI, 평균 킬: 22.333333333333332
#   상대 팀: Bilibili Gaming, 평균 킬: 13.0
#   상대 팀: OKSavingsBank BRION, 평균 킬: 14.11111111111111
#   상대 팀: Team Liquid, 평균 킬: 15.0
#   상대 팀: LNG Esports, 평균 킬: 11.333333333333334
#   상대 팀: Weibo Gaming, 평균 킬: 15.666666666666666
# 팀: Kwangdong Freecs
#   상대 팀: T1, 평균 킬: 9.0
#   상대 팀: KT Rolster, 평균 킬: 10.227272727272727
#   상대 팀: BNK FEARX, 평균 킬: 11.916666666666666
#   상대 팀: DRX, 평균 킬: 10.592592592592593
#   상대 팀: Gen.G, 평균 킬: 8.08695652173913
#   상대 팀: OKSavingsBank Brion, 평균 킬: 9.705882352941176
#   상대 팀: Dplus KIA, 평균 킬: 7.761904761904762
#   상대 팀: Nongshim RedForce, 평균 킬: 12.73913043478261
#   상대 팀: Hanwha Life Esports, 평균 킬: 10.833333333333334
#   상대 팀: OKSavingsBank BRION, 평균 킬: 11.0
# 팀: Nongshim RedForce
#   상대 팀: Hanwha Life Esports, 평균 킬: 9.304347826086957
#   상대 팀: BNK FEARX, 평균 킬: 11.4
#   상대 팀: Dplus KIA, 평균 킬: 7.571428571428571
#   상대 팀: KT Rolster, 평균 킬: 9.666666666666666
#   상대 팀: T1, 평균 킬: 11.73076923076923
#   상대 팀: DRX, 평균 킬: 12.153846153846153
#   상대 팀: OKSavingsBank Brion, 평균 킬: 9.785714285714286
#   상대 팀: Kwangdong Freecs, 평균 킬: 9.869565217391305
#   상대 팀: Gen.G, 평균 킬: 5.55
#   상대 팀: OKSavingsBank BRION, 평균 킬: 11.090909090909092
# 팀: Hanwha Life Esports
#   상대 팀: Nongshim RedForce, 평균 킬: 12.826086956521738
#   상대 팀: OKSavingsBank Brion, 평균 킬: 8.88888888888889
#   상대 팀: KT Rolster, 평균 킬: 8.285714285714286
#   상대 팀: Gen.G, 평균 킬: 7.551724137931035
#   상대 팀: Dplus KIA, 평균 킬: 9.275862068965518
#   상대 팀: BNK FEARX, 평균 킬: 12.2
#   상대 팀: T1, 평균 킬: 11.0
#   상대 팀: DRX, 평균 킬: 15.185185185185185
#   상대 팀: Kwangdong Freecs, 평균 킬: 11.208333333333334
#   상대 팀: OKSavingsBank BRION, 평균 킬: 13.666666666666666
# 팀: KT Rolster
#   상대 팀: Dplus KIA, 평균 킬: 11.40625
#   상대 팀: Kwangdong Freecs, 평균 킬: 14.181818181818182
#   상대 팀: Hanwha Life Esports, 평균 킬: 12.428571428571429
#   상대 팀: Nongshim RedForce, 평균 킬: 13.814814814814815
#   상대 팀: BNK FEARX, 평균 킬: 14.296296296296296
#   상대 팀: Gen.G, 평균 킬: 11.03448275862069
#   상대 팀: DRX, 평균 킬: 14.3
#   상대 팀: OKSavingsBank Brion, 평균 킬: 11.857142857142858
#   상대 팀: T1, 평균 킬: 12.076923076923077
#   상대 팀: OKSavingsBank BRION, 평균 킬: 16.875
#   상대 팀: Bilibili Gaming, 평균 킬: 10.0
#   상대 팀: Weibo Gaming, 평균 킬: 23.0
#   상대 팀: LNG Esports, 평균 킬: 9.0
#   상대 팀: JD Gaming, 평균 킬: 10.0
# 팀: Dplus KIA
#   상대 팀: KT Rolster, 평균 킬: 11.34375
#   상대 팀: Gen.G, 평균 킬: 11.0
#   상대 팀: Nongshim RedForce, 평균 킬: 14.047619047619047
#   상대 팀: OKSavingsBank Brion, 평균 킬: 13.0625
#   상대 팀: Hanwha Life Esports, 평균 킬: 11.586206896551724
#   상대 팀: T1, 평균 킬: 10.32258064516129
#   상대 팀: Kwangdong Freecs, 평균 킬: 14.0
#   상대 팀: BNK FEARX, 평균 킬: 13.76
#   상대 팀: DRX, 평균 킬: 14.357142857142858
#   상대 팀: G2 Esports, 평균 킬: 14.666666666666666
#   상대 팀: JD Gaming, 평균 킬: 16.333333333333332
#   상대 팀: Evil Geniuses, 평균 킬: 16.5
#   상대 팀: OKSavingsBank BRION, 평균 킬: 10.4
#   상대 팀: Team BDS, 평균 킬: 13.0
#   상대 팀: GAM Esports, 평균 킬: 15.0
# 팀: Gen.G
#   상대 팀: DRX, 평균 킬: 15.625
#   상대 팀: Dplus KIA, 평균 킬: 13.243243243243244
#   상대 팀: OKSavingsBank Brion, 평균 킬: 15.4
#   상대 팀: Hanwha Life Esports, 평균 킬: 14.758620689655173
#   상대 팀: Kwangdong Freecs, 평균 킬: 14.26086956521739
#   상대 팀: KT Rolster, 평균 킬: 10.689655172413794
#   상대 팀: BNK FEARX, 평균 킬: 17.03846153846154
#   상대 팀: T1, 평균 킬: 13.169811320754716
#   상대 팀: Nongshim RedForce, 평균 킬: 15.25
#   상대 팀: Royal Never Give Up, 평균 킬: 13.333333333333334
#   상대 팀: 100 Thieves, 평균 킬: 15.0
#   상대 팀: CTBC Flying Oyster, 평균 킬: 23.0
#   상대 팀: G2 Esports, 평균 킬: 18.333333333333332
#   상대 팀: Cloud9, 평균 킬: 17.0
#   상대 팀: Bilibili Gaming, 평균 킬: 10.125
#   상대 팀: OKSavingsBank BRION, 평균 킬: 16.25
#   상대 팀: GAM Esports, 평균 킬: 22.0
# 팀: OKSavingsBank Brion
#   상대 팀: T1, 평균 킬: 9.071428571428571
#   상대 팀: Hanwha Life Esports, 평균 킬: 9.0
#   상대 팀: Gen.G, 평균 킬: 5.7
#   상대 팀: Dplus KIA, 평균 킬: 7.1875
#   상대 팀: DRX, 평균 킬: 8.9375
#   상대 팀: Kwangdong Freecs, 평균 킬: 10.411764705882353
#   상대 팀: Nongshim RedForce, 평균 킬: 13.0
#   상대 팀: KT Rolster, 평균 킬: 10.214285714285714
#   상대 팀: BNK FEARX, 평균 킬: 9.285714285714286
# 팀: MAD Lions KOI
#   상대 팀: Team Vitality, 평균 킬: 15.411764705882353
#   상대 팀: SK Gaming, 평균 킬: 15.5
#   상대 팀: G2 Esports, 평균 킬: 12.7
#   상대 팀: Rogue, 평균 킬: 14.166666666666666
#   상대 팀: Astralis, 평균 킬: 19.571428571428573
#   상대 팀: GiantX, 평균 킬: 12.0625
#   상대 팀: Misfits Gaming, 평균 킬: 10.75
#   상대 팀: Fnatic, 평균 킬: 14.03448275862069
#   상대 팀: Team BDS, 평균 킬: 14.9
#   상대 팀: Isurus, 평균 킬: 22.0
#   상대 팀: İstanbul Wildcats, 평균 킬: 20.0
#   상대 팀: Royal Never Give Up, 평균 킬: 10.0
#   상대 팀: MGN Vikings Esports, 평균 킬: 16.8
#   상대 팀: DRX, 평균 킬: 10.0
#   상대 팀: Evil Geniuses, 평균 킬: 5.333333333333333
#   상대 팀: Team Heretics, 평균 킬: 13.833333333333334
#   상대 팀: T1, 평균 킬: 11.0
#   상대 팀: Cloud9, 평균 킬: 3.0
#   상대 팀: NRG Kia, 평균 킬: 22.0
#   상대 팀: Weibo Gaming, 평균 킬: 10.0
#   상대 팀: Karmine Corp, 평균 킬: 12.5
# 팀: Team Vitality
#   상대 팀: MAD Lions KOI, 평균 킬: 12.647058823529411
#   상대 팀: Fnatic, 평균 킬: 12.88888888888889
#   상대 팀: GiantX, 평균 킬: 13.866666666666667
#   상대 팀: Team BDS, 평균 킬: 12.928571428571429
#   상대 팀: G2 Esports, 평균 킬: 13.5
#   상대 팀: SK Gaming, 평균 킬: 11.076923076923077
#   상대 팀: Rogue, 평균 킬: 9.636363636363637
#   상대 팀: Misfits Gaming, 평균 킬: 18.25
#   상대 팀: Astralis, 평균 킬: 17.0
#   상대 팀: Team Heretics, 평균 킬: 16.125
#   상대 팀: Karmine Corp, 평균 킬: 17.5
# 팀: Rogue
#   상대 팀: SK Gaming, 평균 킬: 10.166666666666666
#   상대 팀: Misfits Gaming, 평균 킬: 17.375
#   상대 팀: Astralis, 평균 킬: 12.142857142857142
#   상대 팀: MAD Lions KOI, 평균 킬: 13.61111111111111
#   상대 팀: Team BDS, 평균 킬: 11.0
#   상대 팀: Fnatic, 평균 킬: 12.555555555555555
#   상대 팀: Team Vitality, 평균 킬: 13.636363636363637
#   상대 팀: GiantX, 평균 킬: 14.777777777777779
#   상대 팀: G2 Esports, 평균 킬: 12.166666666666666
#   상대 팀: DRX, 평균 킬: 9.666666666666666
#   상대 팀: GAM Esports, 평균 킬: 16.5
#   상대 팀: Top Esports, 평균 킬: 13.0
#   상대 팀: JD Gaming, 평균 킬: 7.333333333333333
#   상대 팀: Team Heretics, 평균 킬: 9.714285714285714
#   상대 팀: Karmine Corp, 평균 킬: 15.5
# 팀: SK Gaming
#   상대 팀: Rogue, 평균 킬: 10.25
#   상대 팀: MAD Lions KOI, 평균 킬: 13.642857142857142
#   상대 팀: Fnatic, 평균 킬: 12.875
#   상대 팀: G2 Esports, 평균 킬: 12.272727272727273
#   상대 팀: GiantX, 평균 킬: 12.166666666666666
#   상대 팀: Team Vitality, 평균 킬: 13.076923076923077
#   상대 팀: Team BDS, 평균 킬: 9.714285714285714
#   상대 팀: Astralis, 평균 킬: 13.714285714285714
#   상대 팀: Misfits Gaming, 평균 킬: 11.5
#   상대 팀: Team Heretics, 평균 킬: 12.2
#   상대 팀: Karmine Corp, 평균 킬: 15.5
# 팀: GiantX
#   상대 팀: G2 Esports, 평균 킬: 10.368421052631579
#   상대 팀: Team BDS, 평균 킬: 11.0
#   상대 팀: Team Vitality, 평균 킬: 15.066666666666666
#   상대 팀: Misfits Gaming, 평균 킬: 14.25
#   상대 팀: SK Gaming, 평균 킬: 9.416666666666666
#   상대 팀: MAD Lions KOI, 평균 킬: 13.25
#   상대 팀: Astralis, 평균 킬: 11.285714285714286
#   상대 팀: Rogue, 평균 킬: 10.444444444444445
#   상대 팀: Fnatic, 평균 킬: 14.26086956521739
#   상대 팀: Team Heretics, 평균 킬: 14.2
#   상대 팀: Karmine Corp, 평균 킬: 12.5
# 팀: G2 Esports
#   상대 팀: GiantX, 평균 킬: 20.894736842105264
#   상대 팀: Astralis, 평균 킬: 15.857142857142858
#   상대 팀: MAD Lions KOI, 평균 킬: 17.433333333333334
#   상대 팀: SK Gaming, 평균 킬: 15.090909090909092
#   상대 팀: Team Vitality, 평균 킬: 12.75
#   상대 팀: Misfits Gaming, 평균 킬: 19.818181818181817
#   상대 팀: Fnatic, 평균 킬: 17.26086956521739
#   상대 팀: Team BDS, 평균 킬: 18.476190476190474
#   상대 팀: Rogue, 평균 킬: 13.066666666666666
#   상대 팀: ORDER, 평균 킬: 20.25
#   상대 팀: Evil Geniuses, 평균 킬: 16.625
#   상대 팀: T1, 평균 킬: 10.4
#   상대 팀: Royal Never Give Up, 평균 킬: 13.5
#   상대 팀: MGN Vikings Esports, 평균 킬: 14.5
#   상대 팀: PSG Talon, 평균 킬: 16.75
#   상대 팀: Dplus KIA, 평균 킬: 8.333333333333334
#   상대 팀: JD Gaming, 평균 킬: 12.5
#   상대 팀: Team Heretics, 평균 킬: 16.4
#   상대 팀: LOUD, 평균 킬: 22.5
#   상대 팀: Gen.G, 평균 킬: 8.833333333333334
#   상대 팀: Bilibili Gaming, 평균 킬: 11.714285714285714
#   상대 팀: Weibo Gaming, 평균 킬: 26.0
#   상대 팀: NRG Kia, 평균 킬: 5.0
#   상대 팀: Karmine Corp, 평균 킬: 13.0
# 팀: Astralis
#   상대 팀: Misfits Gaming, 평균 킬: 14.25
#   상대 팀: G2 Esports, 평균 킬: 10.428571428571429
#   상대 팀: Rogue, 평균 킬: 10.285714285714286
#   상대 팀: Fnatic, 평균 킬: 12.5
#   상대 팀: MAD Lions KOI, 평균 킬: 10.928571428571429
#   상대 팀: Team BDS, 평균 킬: 12.4
#   상대 팀: GiantX, 평균 킬: 10.857142857142858
#   상대 팀: SK Gaming, 평균 킬: 11.857142857142858
#   상대 팀: Team Vitality, 평균 킬: 13.88888888888889
#   상대 팀: Team Heretics, 평균 킬: 13.333333333333334
# 팀: Misfits Gaming
#   상대 팀: Astralis, 평균 킬: 17.25
#   상대 팀: Rogue, 평균 킬: 11.375
#   상대 팀: Team BDS, 평균 킬: 17.5
#   상대 팀: GiantX, 평균 킬: 12.0
#   상대 팀: Fnatic, 평균 킬: 14.5
#   상대 팀: G2 Esports, 평균 킬: 10.818181818181818
#   상대 팀: MAD Lions KOI, 평균 킬: 19.75
#   상대 팀: Team Vitality, 평균 킬: 5.75
#   상대 팀: SK Gaming, 평균 킬: 17.0
# 팀: Fnatic
#   상대 팀: Team BDS, 평균 킬: 13.142857142857142
#   상대 팀: Team Vitality, 평균 킬: 14.666666666666666
#   상대 팀: SK Gaming, 평균 킬: 12.875
#   상대 팀: Astralis, 평균 킬: 14.6
#   상대 팀: Misfits Gaming, 평균 킬: 17.75
#   상대 팀: Rogue, 평균 킬: 12.38888888888889
#   상대 팀: G2 Esports, 평균 킬: 12.91304347826087
#   상대 팀: MAD Lions KOI, 평균 킬: 15.068965517241379
#   상대 팀: GiantX, 평균 킬: 13.0
#   상대 팀: Evil Geniuses, 평균 킬: 10.0
#   상대 팀: Chiefs Esports Club, 평균 킬: 17.0
#   상대 팀: DetonatioN FocusMe, 평균 킬: 20.0
#   상대 팀: LOUD, 평균 킬: 6.0
#   상대 팀: Beyond Gaming, 평균 킬: 23.0
#   상대 팀: Cloud9, 평균 킬: 14.4
#   상대 팀: T1, 평균 킬: 13.0
#   상대 팀: EDward Gaming, 평균 킬: 5.5
#   상대 팀: Team Heretics, 평균 킬: 17.22222222222222
#   상대 팀: LNG Esports, 평균 킬: 9.0
#   상대 팀: GAM Esports, 평균 킬: 18.0
#   상대 팀: Bilibili Gaming, 평균 킬: 8.0
#   상대 팀: Weibo Gaming, 평균 킬: 9.0
#   상대 팀: Karmine Corp, 평균 킬: 21.0
# 팀: Team BDS
#   상대 팀: Fnatic, 평균 킬: 13.714285714285714
#   상대 팀: GiantX, 평균 킬: 15.333333333333334
#   상대 팀: Misfits Gaming, 평균 킬: 8.25
#   상대 팀: Team Vitality, 평균 킬: 15.571428571428571
#   상대 팀: Rogue, 평균 킬: 13.454545454545455
#   상대 팀: Astralis, 평균 킬: 10.9
#   상대 팀: SK Gaming, 평균 킬: 13.642857142857142
#   상대 팀: G2 Esports, 평균 킬: 10.904761904761905
#   상대 팀: MAD Lions KOI, 평균 킬: 13.15
#   상대 팀: Team Heretics, 평균 킬: 12.416666666666666
#   상대 팀: Golden Guardians, 평균 킬: 13.666666666666666
#   상대 팀: Team Whales, 평균 킬: 9.333333333333334
#   상대 팀: DetonatioN FocusMe, 평균 킬: 15.0
#   상대 팀: CTBC Flying Oyster, 평균 킬: 18.5
#   상대 팀: PSG Talon, 평균 킬: 13.4
#   상대 팀: JD Gaming, 평균 킬: 6.0
#   상대 팀: Dplus KIA, 평균 킬: 5.0
#   상대 팀: Karmine Corp, 평균 킬: 11.5
# 팀: TSM
#   상대 팀: 100 Thieves, 평균 킬: 5.333333333333333
#   상대 팀: FlyQuest, 평균 킬: 12.5
#   상대 팀: Cloud9, 평균 킬: 10.11111111111111
#   상대 팀: Golden Guardians, 평균 킬: 11.777777777777779
#   상대 팀: Evil Geniuses, 평균 킬: 8.722222222222221
#   상대 팀: Dignitas, 평균 킬: 12.23076923076923
#   상대 팀: Immortals, 평균 킬: 13.75
#   상대 팀: NRG Kia, 평균 킬: 15.125
#   상대 팀: Team Liquid, 평균 킬: 13.5
# 팀: 100 Thieves
#   상대 팀: TSM, 평균 킬: 17.88888888888889
#   상대 팀: Golden Guardians, 평균 킬: 15.428571428571429
#   상대 팀: FlyQuest, 평균 킬: 8.642857142857142
#   상대 팀: Cloud9, 평균 킬: 10.875
#   상대 팀: Dignitas, 평균 킬: 13.076923076923077
#   상대 팀: Team Liquid, 평균 킬: 12.285714285714286
#   상대 팀: NRG Kia, 평균 킬: 14.875
#   상대 팀: Immortals, 평균 킬: 13.4
#   상대 팀: Evil Geniuses, 평균 킬: 10.411764705882353
#   상대 팀: CTBC Flying Oyster, 평균 킬: 14.5
#   상대 팀: Gen.G, 평균 킬: 5.0
#   상대 팀: Royal Never Give Up, 평균 킬: 7.0
#   상대 팀: Shopify Rebellion, 평균 킬: 19.5
# 팀: Cloud9
#   상대 팀: Golden Guardians, 평균 킬: 14.238095238095237
#   상대 팀: FlyQuest, 평균 킬: 14.0
#   상대 팀: TSM, 평균 킬: 17.0
#   상대 팀: 100 Thieves, 평균 킬: 14.916666666666666
#   상대 팀: NRG Kia, 평균 킬: 13.344827586206897
#   상대 팀: Evil Geniuses, 평균 킬: 13.047619047619047
#   상대 팀: Team Liquid, 평균 킬: 10.538461538461538
#   상대 팀: Immortals, 평균 킬: 12.8
#   상대 팀: Dignitas, 평균 킬: 14.3
#   상대 팀: Fnatic, 평균 킬: 15.6
#   상대 팀: EDward Gaming, 평균 킬: 2.5
#   상대 팀: T1, 평균 킬: 3.6666666666666665
#   상대 팀: Bilibili Gaming, 평균 킬: 13.666666666666666
#   상대 팀: Gen.G, 평균 킬: 5.333333333333333
#   상대 팀: MAD Lions KOI, 평균 킬: 10.0
#   상대 팀: LNG Esports, 평균 킬: 6.0
#   상대 팀: Shopify Rebellion, 평균 킬: 14.0
# 팀: Golden Guardians
#   상대 팀: Cloud9, 평균 킬: 8.952380952380953
#   상대 팀: 100 Thieves, 평균 킬: 11.214285714285714
#   상대 팀: FlyQuest, 평균 킬: 12.866666666666667
#   상대 팀: TSM, 평균 킬: 15.222222222222221
#   상대 팀: Evil Geniuses, 평균 킬: 10.923076923076923
#   상대 팀: NRG Kia, 평균 킬: 12.941176470588236
#   상대 팀: Dignitas, 평균 킬: 16.454545454545453
#   상대 팀: Team Liquid, 평균 킬: 12.384615384615385
#   상대 팀: Immortals, 평균 킬: 15.125
#   상대 팀: GAM Esports, 평균 킬: 19.5
#   상대 팀: Bilibili Gaming, 평균 킬: 13.666666666666666
#   상대 팀: Movistar R7, 평균 킬: 19.5
#   상대 팀: PSG Talon, 평균 킬: 16.666666666666668
#   상대 팀: JD Gaming, 평균 킬: 8.333333333333334
#   상대 팀: Team BDS, 평균 킬: 3.6666666666666665
# 팀: FlyQuest
#   상대 팀: TSM, 평균 킬: 12.857142857142858
#   상대 팀: Cloud9, 평균 킬: 10.157894736842104
#   상대 팀: 100 Thieves, 평균 킬: 13.714285714285714
#   상대 팀: Golden Guardians, 평균 킬: 12.533333333333333
#   상대 팀: Team Liquid, 평균 킬: 11.56
#   상대 팀: NRG Kia, 평균 킬: 14.8
#   상대 팀: Dignitas, 평균 킬: 14.1
#   상대 팀: Evil Geniuses, 평균 킬: 10.461538461538462
#   상대 팀: Immortals, 평균 킬: 12.5
#   상대 팀: Shopify Rebellion, 평균 킬: 9.5
# 팀: Dignitas
#   상대 팀: Team Liquid, 평균 킬: 8.38888888888889
#   상대 팀: Immortals, 평균 킬: 13.818181818181818
#   상대 팀: NRG Kia, 평균 킬: 10.833333333333334
#   상대 팀: Evil Geniuses, 평균 킬: 8.555555555555555
#   상대 팀: 100 Thieves, 평균 킬: 11.615384615384615
#   상대 팀: TSM, 평균 킬: 12.76923076923077
#   상대 팀: FlyQuest, 평균 킬: 8.2
#   상대 팀: Golden Guardians, 평균 킬: 9.272727272727273
#   상대 팀: Cloud9, 평균 킬: 7.5
#   상대 팀: Shopify Rebellion, 평균 킬: 19.5
# 팀: Team Liquid
#   상대 팀: Dignitas, 평균 킬: 14.277777777777779
#   상대 팀: Evil Geniuses, 평균 킬: 12.758620689655173
#   상대 팀: NRG Kia, 평균 킬: 12.307692307692308
#   상대 팀: Immortals, 평균 킬: 16.727272727272727
#   상대 팀: FlyQuest, 평균 킬: 15.84
#   상대 팀: 100 Thieves, 평균 킬: 12.214285714285714
#   상대 팀: Cloud9, 평균 킬: 12.23076923076923
#   상대 팀: Golden Guardians, 평균 킬: 14.461538461538462
#   상대 팀: TSM, 평균 킬: 13.125
#   상대 팀: T1, 평균 킬: 14.0
#   상대 팀: GAM Esports, 평균 킬: 8.666666666666666
#   상대 팀: Shopify Rebellion, 평균 킬: 15.5
# 팀: NRG Kia
#   상대 팀: Immortals, 평균 킬: 13.727272727272727
#   상대 팀: Evil Geniuses, 평균 킬: 10.666666666666666
#   상대 팀: Team Liquid, 평균 킬: 13.038461538461538
#   상대 팀: Dignitas, 평균 킬: 11.75
#   상대 팀: Cloud9, 평균 킬: 13.517241379310345
#   상대 팀: FlyQuest, 평균 킬: 13.7
#   상대 팀: 100 Thieves, 평균 킬: 11.1875
#   상대 팀: Golden Guardians, 평균 킬: 15.470588235294118
#   상대 팀: TSM, 평균 킬: 11.125
#   상대 팀: Weibo Gaming, 평균 킬: 6.25
#   상대 팀: MAD Lions KOI, 평균 킬: 24.0
#   상대 팀: G2 Esports, 평균 킬: 21.5
#   상대 팀: Shopify Rebellion, 평균 킬: 9.0
# 팀: Immortals
#   상대 팀: NRG Kia, 평균 킬: 13.636363636363637
#   상대 팀: Dignitas, 평균 킬: 11.181818181818182
#   상대 팀: Evil Geniuses, 평균 킬: 9.444444444444445
#   상대 팀: Team Liquid, 평균 킬: 6.363636363636363
#   상대 팀: 100 Thieves, 평균 킬: 8.3
#   상대 팀: Cloud9, 평균 킬: 7.7
#   상대 팀: TSM, 평균 킬: 9.5
#   상대 팀: FlyQuest, 평균 킬: 8.7
#   상대 팀: Golden Guardians, 평균 킬: 8.5
#   상대 팀: Shopify Rebellion, 평균 킬: 16.0
# 팀: Evil Geniuses
#   상대 팀: Team Liquid, 평균 킬: 13.241379310344827
#   상대 팀: NRG Kia, 평균 킬: 17.5
#   상대 팀: Immortals, 평균 킬: 15.666666666666666
#   상대 팀: Dignitas, 평균 킬: 12.444444444444445
#   상대 팀: Golden Guardians, 평균 킬: 11.076923076923077
#   상대 팀: Cloud9, 평균 킬: 12.428571428571429
#   상대 팀: TSM, 평균 킬: 15.277777777777779
#   상대 팀: 100 Thieves, 평균 킬: 12.117647058823529
#   상대 팀: FlyQuest, 평균 킬: 15.23076923076923
#   상대 팀: G2 Esports, 평균 킬: 9.625
#   상대 팀: ORDER, 평균 킬: 20.5
#   상대 팀: Royal Never Give Up, 평균 킬: 9.4
#   상대 팀: MGN Vikings Esports, 평균 킬: 24.0
#   상대 팀: PSG Talon, 평균 킬: 20.5
#   상대 팀: T1, 평균 킬: 13.0
#   상대 팀: Fnatic, 평균 킬: 2.0
#   상대 팀: LOUD, 평균 킬: 25.5
#   상대 팀: Beyond Gaming, 평균 킬: 16.0
#   상대 팀: Chiefs Esports Club, 평균 킬: 19.0
#   상대 팀: DetonatioN FocusMe, 평균 킬: 18.0
#   상대 팀: MAD Lions KOI, 평균 킬: 16.333333333333332
#   상대 팀: JD Gaming, 평균 킬: 10.0
#   상대 팀: Dplus KIA, 평균 킬: 8.0
# 팀: LOUD
#   상대 팀: FURIA, 평균 킬: 17.46153846153846
#   상대 팀: RED Canids, 평균 킬: 15.428571428571429
#   상대 팀: Los Grandes, 평균 킬: 15.428571428571429
#   상대 팀: Liberty, 평균 킬: 17.8
#   상대 팀: INTZ, 평균 킬: 21.3
#   상대 팀: KaBuM! Esports, 평균 킬: 13.6
#   상대 팀: paiN Gaming, 평균 킬: 14.6875
#   상대 팀: Miners, 평균 킬: 13.25
#   상대 팀: Rensga eSports, 평균 킬: 22.0
#   상대 팀: Beyond Gaming, 평균 킬: 3.0
#   상대 팀: DetonatioN FocusMe, 평균 킬: 14.571428571428571
#   상대 팀: Evil Geniuses, 평균 킬: 9.5
#   상대 팀: Fnatic, 평균 킬: 20.0
#   상대 팀: Chiefs Esports Club, 평균 킬: 29.0
#   상대 팀: Fluxo, 평균 킬: 9.333333333333334
#   상대 팀: Vivo Keyd Stars, 평균 킬: 14.5
#   상대 팀: G2 Esports, 평균 킬: 10.5
#   상대 팀: PSG Talon, 평균 킬: 7.5
#   상대 팀: GAM Esports, 평균 킬: 12.5
# 팀: FURIA
#   상대 팀: LOUD, 평균 킬: 12.846153846153847
#   상대 팀: Los Grandes, 평균 킬: 13.0
#   상대 팀: INTZ, 평균 킬: 15.3
#   상대 팀: paiN Gaming, 평균 킬: 13.31578947368421
#   상대 팀: RED Canids, 평균 킬: 12.291666666666666
#   상대 팀: Rensga eSports, 평균 킬: 15.5
#   상대 팀: Liberty, 평균 킬: 12.3
#   상대 팀: KaBuM! Esports, 평균 킬: 12.7
#   상대 팀: Miners, 평균 킬: 20.25
#   상대 팀: Vivo Keyd Stars, 평균 킬: 11.666666666666666
#   상대 팀: Fluxo, 평균 킬: 12.222222222222221
# 팀: Miners
#   상대 팀: Los Grandes, 평균 킬: 16.75
#   상대 팀: INTZ, 평균 킬: 17.75
#   상대 팀: paiN Gaming, 평균 킬: 6.75
#   상대 팀: Rensga eSports, 평균 킬: 18.25
#   상대 팀: RED Canids, 평균 킬: 11.75
#   상대 팀: Liberty, 평균 킬: 10.714285714285714
#   상대 팀: KaBuM! Esports, 평균 킬: 8.714285714285714
#   상대 팀: LOUD, 평균 킬: 11.5
#   상대 팀: FURIA, 평균 킬: 14.25
# 팀: Los Grandes
#   상대 팀: Miners, 평균 킬: 6.25
#   상대 팀: FURIA, 평균 킬: 12.0
#   상대 팀: LOUD, 평균 킬: 12.785714285714286
#   상대 팀: INTZ, 평균 킬: 16.0
#   상대 팀: paiN Gaming, 평균 킬: 9.933333333333334
#   상대 팀: Rensga eSports, 평균 킬: 17.0
#   상대 팀: RED Canids, 평균 킬: 11.615384615384615
#   상대 팀: Liberty, 평균 킬: 14.9
#   상대 팀: KaBuM! Esports, 평균 킬: 11.9
#   상대 팀: Fluxo, 평균 킬: 13.333333333333334
#   상대 팀: Vivo Keyd Stars, 평균 킬: 11.833333333333334
# 팀: KaBuM! Esports
#   상대 팀: INTZ, 평균 킬: 12.3
#   상대 팀: paiN Gaming, 평균 킬: 11.470588235294118
#   상대 팀: Rensga eSports, 평균 킬: 20.5
#   상대 팀: RED Canids, 평균 킬: 14.952380952380953
#   상대 팀: Liberty, 평균 킬: 15.9
#   상대 팀: LOUD, 평균 킬: 15.0
#   상대 팀: Miners, 평균 킬: 22.0
#   상대 팀: FURIA, 평균 킬: 12.3
#   상대 팀: Los Grandes, 평균 킬: 14.2
#   상대 팀: Fluxo, 평균 킬: 11.833333333333334
#   상대 팀: Vivo Keyd Stars, 평균 킬: 16.166666666666668
# 팀: INTZ
#   상대 팀: KaBuM! Esports, 평균 킬: 14.7
#   상대 팀: Miners, 평균 킬: 12.75
#   상대 팀: FURIA, 평균 킬: 10.5
#   상대 팀: Los Grandes, 평균 킬: 9.8
#   상대 팀: LOUD, 평균 킬: 11.1
#   상대 팀: paiN Gaming, 평균 킬: 11.923076923076923
#   상대 팀: Rensga eSports, 평균 킬: 13.75
#   상대 팀: RED Canids, 평균 킬: 12.5
#   상대 팀: Liberty, 평균 킬: 13.1
#   상대 팀: Fluxo, 평균 킬: 15.666666666666666
#   상대 팀: Vivo Keyd Stars, 평균 킬: 14.7
# 팀: Rensga eSports
#   상대 팀: RED Canids, 평균 킬: 9.25
#   상대 팀: Liberty, 평균 킬: 7.0
#   상대 팀: KaBuM! Esports, 평균 킬: 8.75
#   상대 팀: Miners, 평균 킬: 11.25
#   상대 팀: FURIA, 평균 킬: 18.75
#   상대 팀: Los Grandes, 평균 킬: 13.5
#   상대 팀: INTZ, 평균 킬: 9.0
#   상대 팀: paiN Gaming, 평균 킬: 8.25
#   상대 팀: LOUD, 평균 킬: 12.0
# 팀: RED Canids
#   상대 팀: Rensga eSports, 평균 킬: 17.0
#   상대 팀: LOUD, 평균 킬: 14.761904761904763
#   상대 팀: Liberty, 평균 킬: 15.533333333333333
#   상대 팀: KaBuM! Esports, 평균 킬: 18.142857142857142
#   상대 팀: Miners, 평균 킬: 16.5
#   상대 팀: FURIA, 평균 킬: 12.5
#   상대 팀: Los Grandes, 평균 킬: 18.0
#   상대 팀: INTZ, 평균 킬: 21.071428571428573
#   상대 팀: paiN Gaming, 평균 킬: 13.434782608695652
#   상대 팀: PSG Talon, 평균 킬: 7.0
#   상대 팀: İstanbul Wildcats, 평균 킬: 23.0
#   상대 팀: Royal Never Give Up, 평균 킬: 7.333333333333333
#   상대 팀: Vivo Keyd Stars, 평균 킬: 14.5
#   상대 팀: Fluxo, 평균 킬: 11.833333333333334
# 팀: Liberty
#   상대 팀: Rensga eSports, 평균 킬: 16.5
#   상대 팀: paiN Gaming, 평균 킬: 10.9
#   상대 팀: RED Canids, 평균 킬: 11.4
#   상대 팀: LOUD, 평균 킬: 9.5
#   상대 팀: KaBuM! Esports, 평균 킬: 13.6
#   상대 팀: Miners, 평균 킬: 17.571428571428573
#   상대 팀: FURIA, 평균 킬: 9.7
#   상대 팀: Los Grandes, 평균 킬: 10.1
#   상대 팀: INTZ, 평균 킬: 13.6
#   상대 팀: Fluxo, 평균 킬: 10.833333333333334
#   상대 팀: Vivo Keyd Stars, 평균 킬: 13.0
# 팀: paiN Gaming
#   상대 팀: Liberty, 평균 킬: 12.6
#   상대 팀: KaBuM! Esports, 평균 킬: 14.705882352941176
#   상대 팀: Miners, 평균 킬: 15.25
#   상대 팀: FURIA, 평균 킬: 14.368421052631579
#   상대 팀: Los Grandes, 평균 킬: 14.6
#   상대 팀: INTZ, 평균 킬: 17.46153846153846
#   상대 팀: LOUD, 평균 킬: 12.46875
#   상대 팀: Rensga eSports, 평균 킬: 16.25
#   상대 팀: RED Canids, 평균 킬: 14.043478260869565
#   상대 팀: Vivo Keyd Stars, 평균 킬: 18.0
#   상대 팀: Fluxo, 평균 킬: 16.166666666666668
# 팀: Deep Cross Gaming
#   상대 팀: J Team, 평균 킬: 13.277777777777779
#   상대 팀: Frank Esports, 평균 킬: 12.0
#   상대 팀: HELL PIGS, 평균 킬: 21.166666666666668
#   상대 팀: West Point Esports, 평균 킬: 19.666666666666668
#   상대 팀: Beyond Gaming, 평균 킬: 13.0
#   상대 팀: CTBC Flying Oyster, 평균 킬: 11.066666666666666
#   상대 팀: Impunity, 평균 킬: 17.75
#   상대 팀: Dewish Team, 평균 킬: 18.125
#   상대 팀: PSG Talon, 평균 킬: 9.761904761904763
#   상대 팀: Team Bliss, 평균 킬: 24.0
#   상대 팀: Chiefs Esports Club, 평균 킬: 16.0
#   상대 팀: Ground Zero Gaming, 평균 킬: 30.0
#   상대 팀: DetonatioN FocusMe, 평균 킬: 15.4
#   상대 팀: Fukuoka SoftBank HAWKS gaming, 평균 킬: 13.4
# 팀: J Team
#   상대 팀: Deep Cross Gaming, 평균 킬: 12.444444444444445
#   상대 팀: Impunity, 평균 킬: 19.375
#   상대 팀: Dewish Team, 평균 킬: 23.0
#   상대 팀: Frank Esports, 평균 킬: 9.153846153846153
#   상대 팀: CTBC Flying Oyster, 평균 킬: 9.23076923076923
#   상대 팀: Beyond Gaming, 평균 킬: 11.136363636363637
#   상대 팀: West Point Esports, 평균 킬: 19.666666666666668
#   상대 팀: HELL PIGS, 평균 킬: 19.733333333333334
#   상대 팀: PSG Talon, 평균 킬: 10.166666666666666
#   상대 팀: DetonatioN FocusMe, 평균 킬: 9.2
#   상대 팀: Antic Esports, 평균 킬: 26.0
# 팀: Team Whales
#   상대 팀: , 평균 킬: 24.25
#   상대 팀: MGN Vikings Esports, 평균 킬: 14.727272727272727
#   상대 팀: SBTC Esports, 평균 킬: 13.565217391304348
#   상대 팀: Team Flash, 평균 킬: 15.473684210526315
#   상대 팀: GAM Esports, 평균 킬: 13.416666666666666
#   상대 팀: Team Secret, 평균 킬: 12.942857142857143
#   상대 팀: CERBERUS Esports, 평균 킬: 15.258064516129032
#   상대 팀: AS Esports, 평균 킬: 18.2
#   상대 팀: Genius Esports, 평균 킬: 18.5
#   상대 팀: MGN Blue Esports, 평균 킬: 20.545454545454547
#   상대 팀: Team BDS, 평균 킬: 12.333333333333334
#   상대 팀: CTBC Flying Oyster, 평균 킬: 13.666666666666666
#   상대 팀: Rainbow Warriors, 평균 킬: 22.75
# 팀: Frank Esports
#   상대 팀: Impunity, 평균 킬: 19.066666666666666
#   상대 팀: CTBC Flying Oyster, 평균 킬: 11.027027027027026
#   상대 팀: Deep Cross Gaming, 평균 킬: 12.791666666666666
#   상대 팀: J Team, 평균 킬: 14.23076923076923
#   상대 팀: PSG Talon, 평균 킬: 8.375
#   상대 팀: Dewish Team, 평균 킬: 17.375
#   상대 팀: Beyond Gaming, 평균 킬: 13.38888888888889
#   상대 팀: HELL PIGS, 평균 킬: 15.538461538461538
#   상대 팀: West Point Esports, 평균 킬: 20.1
#   상대 팀: Chiefs Esports Club, 평균 킬: 13.5
#   상대 팀: Antic Esports, 평균 킬: 22.5
#   상대 팀: DetonatioN FocusMe, 평균 킬: 11.0
#   상대 팀: Fukuoka SoftBank HAWKS gaming, 평균 킬: 17.0
# 팀: Impunity
#   상대 팀: Frank Esports, 평균 킬: 9.866666666666667
#   상대 팀: J Team, 평균 킬: 5.0
#   상대 팀: PSG Talon, 평균 킬: 7.615384615384615
#   상대 팀: CTBC Flying Oyster, 평균 킬: 8.0
#   상대 팀: HELL PIGS, 평균 킬: 12.875
#   상대 팀: West Point Esports, 평균 킬: 18.375
#   상대 팀: Deep Cross Gaming, 평균 킬: 9.875
#   상대 팀: Beyond Gaming, 평균 킬: 10.8125
#   상대 팀: Dewish Team, 평균 킬: 20.454545454545453
#   상대 팀: Team Bliss, 평균 킬: 25.666666666666668
#   상대 팀: PSG Talon Academy, 평균 킬: 6.0
# 팀: HELL PIGS
#   상대 팀: Dewish Team, 평균 킬: 18.375
#   상대 팀: Beyond Gaming, 평균 킬: 10.363636363636363
#   상대 팀: CTBC Flying Oyster, 평균 킬: 6.461538461538462
#   상대 팀: Deep Cross Gaming, 평균 킬: 11.75
#   상대 팀: Impunity, 평균 킬: 16.875
#   상대 팀: PSG Talon, 평균 킬: 7.0
#   상대 팀: West Point Esports, 평균 킬: 17.615384615384617
#   상대 팀: Frank Esports, 평균 킬: 9.384615384615385
#   상대 팀: J Team, 평균 킬: 8.533333333333333
# 팀: Dewish Team
#   상대 팀: HELL PIGS, 평균 킬: 11.75
#   상대 팀: PSG Talon, 평균 킬: 5.875
#   상대 팀: J Team, 평균 킬: 6.0
#   상대 팀: Beyond Gaming, 평균 킬: 4.875
#   상대 팀: West Point Esports, 평균 킬: 16.0
#   상대 팀: Frank Esports, 평균 킬: 7.0
#   상대 팀: CTBC Flying Oyster, 평균 킬: 6.5
#   상대 팀: Deep Cross Gaming, 평균 킬: 7.25
#   상대 팀: Impunity, 평균 킬: 10.545454545454545
#   상대 팀: , 평균 킬: 9.0
# 팀: PSG Talon
#   상대 팀: Beyond Gaming, 평균 킬: 14.692307692307692
#   상대 팀: Dewish Team, 평균 킬: 20.5
#   상대 팀: Impunity, 평균 킬: 15.0
#   상대 팀: West Point Esports, 평균 킬: 18.7
#   상대 팀: Frank Esports, 평균 킬: 12.4375
#   상대 팀: HELL PIGS, 평균 킬: 21.6
#   상대 팀: J Team, 평균 킬: 12.61111111111111
#   상대 팀: CTBC Flying Oyster, 평균 킬: 11.9
#   상대 팀: Deep Cross Gaming, 평균 킬: 16.19047619047619
#   상대 팀: RED Canids, 평균 킬: 7.0
#   상대 팀: Royal Never Give Up, 평균 킬: 7.8
#   상대 팀: İstanbul Wildcats, 평균 킬: 19.5
#   상대 팀: MGN Vikings Esports, 평균 킬: 17.0
#   상대 팀: T1, 평균 킬: 10.5
#   상대 팀: Evil Geniuses, 평균 킬: 4.0
#   상대 팀: G2 Esports, 평균 킬: 14.75
#   상대 팀: DetonatioN FocusMe, 평균 킬: 21.0
#   상대 팀: LOUD, 평균 킬: 21.0
#   상대 팀: Golden Guardians, 평균 킬: 8.333333333333334
#   상대 팀: Movistar R7, 평균 킬: 15.0
#   상대 팀: Team BDS, 평균 킬: 12.6
#   상대 팀: Fukuoka SoftBank HAWKS gaming, 평균 킬: 16.875
# 팀: Beyond Gaming
#   상대 팀: PSG Talon, 평균 킬: 8.961538461538462
#   상대 팀: HELL PIGS, 평균 킬: 16.09090909090909
#   상대 팀: Dewish Team, 평균 킬: 20.5
#   상대 팀: Deep Cross Gaming, 평균 킬: 15.904761904761905
#   상대 팀: West Point Esports, 평균 킬: 20.2
#   상대 팀: J Team, 평균 킬: 14.136363636363637
#   상대 팀: Frank Esports, 평균 킬: 11.11111111111111
#   상대 팀: Impunity, 평균 킬: 15.6875
#   상대 팀: CTBC Flying Oyster, 평균 킬: 11.04
#   상대 팀: LOUD, 평균 킬: 21.0
#   상대 팀: Evil Geniuses, 평균 킬: 5.0
#   상대 팀: DetonatioN FocusMe, 평균 킬: 20.0
#   상대 팀: Chiefs Esports Club, 평균 킬: 16.8
#   상대 팀: Fnatic, 평균 킬: 7.0
#   상대 팀: Team Bliss, 평균 킬: 24.333333333333332
#   상대 팀: V3 Esports, 평균 킬: 19.0
# 팀: SBTC Esports
#   상대 팀: Team Secret, 평균 킬: 12.6
#   상대 팀: , 평균 킬: 10.333333333333334
#   상대 팀: Team Whales, 평균 킬: 15.391304347826088
#   상대 팀: CERBERUS Esports, 평균 킬: 15.0
#   상대 팀: MGN Vikings Esports, 평균 킬: 12.352941176470589
#   상대 팀: Team Flash, 평균 킬: 15.0
#   상대 팀: GAM Esports, 평균 킬: 13.5
#   상대 팀: Genius Esports, 평균 킬: 17.6
#   상대 팀: AS Esports, 평균 킬: 18.75
#   상대 팀: MGN Blue Esports, 평균 킬: 15.5
# 팀: Team Secret
#   상대 팀: SBTC Esports, 평균 킬: 17.6
#   상대 팀: GAM Esports, 평균 킬: 11.35483870967742
#   상대 팀: MGN Vikings Esports, 평균 킬: 12.848484848484848
#   상대 팀: , 평균 킬: 19.6
#   상대 팀: CERBERUS Esports, 평균 킬: 14.64516129032258
#   상대 팀: Team Whales, 평균 킬: 14.685714285714285
#   상대 팀: Team Flash, 평균 킬: 12.666666666666666
#   상대 팀: Genius Esports, 평균 킬: 20.6
#   상대 팀: AS Esports, 평균 킬: 19.75
#   상대 팀: MGN Blue Esports, 평균 킬: 17.928571428571427
#   상대 팀: Rainbow Warriors, 평균 킬: 22.5
# 팀: CTBC Flying Oyster
#   상대 팀: Frank Esports, 평균 킬: 13.0
#   상대 팀: HELL PIGS, 평균 킬: 17.153846153846153
#   상대 팀: West Point Esports, 평균 킬: 17.9
#   상대 팀: Impunity, 평균 킬: 15.5
#   상대 팀: J Team, 평균 킬: 13.0
#   상대 팀: Deep Cross Gaming, 평균 킬: 13.666666666666666
#   상대 팀: Dewish Team, 평균 킬: 17.5
#   상대 팀: Beyond Gaming, 평균 킬: 13.2
#   상대 팀: PSG Talon, 평균 킬: 9.975
#   상대 팀: 100 Thieves, 평균 킬: 10.0
#   상대 팀: Royal Never Give Up, 평균 킬: 5.5
#   상대 팀: Gen.G, 평균 킬: 8.5
#   상대 팀: Chiefs Esports Club, 평균 킬: 19.666666666666668
#   상대 팀: Team Bliss, 평균 킬: 19.333333333333332
#   상대 팀: DetonatioN FocusMe, 평균 킬: 18.5
#   상대 팀: Team Whales, 평균 킬: 12.666666666666666
#   상대 팀: Team BDS, 평균 킬: 12.0
#   상대 팀: Fukuoka SoftBank HAWKS gaming, 평균 킬: 12.333333333333334
# 팀: MGN Vikings Esports
#   상대 팀: Team Flash, 평균 킬: 16.464285714285715
#   상대 팀: Team Whales, 평균 킬: 13.515151515151516
#   상대 팀: Team Secret, 평균 킬: 17.03030303030303
#   상대 팀: GAM Esports, 평균 킬: 13.422222222222222
#   상대 팀: SBTC Esports, 평균 킬: 15.352941176470589
#   상대 팀: CERBERUS Esports, 평균 킬: 15.041666666666666
#   상대 팀: , 평균 킬: 19.2
#   상대 팀: T1, 평균 킬: 7.75
#   상대 팀: DetonatioN FocusMe, 평균 킬: 23.5
#   상대 팀: Team Aze, 평균 킬: 22.5
#   상대 팀: PSG Talon, 평균 킬: 14.0
#   상대 팀: Evil Geniuses, 평균 킬: 11.0
#   상대 팀: G2 Esports, 평균 킬: 12.0
#   상대 팀: Royal Never Give Up, 평균 킬: 13.666666666666666
#   상대 팀: Genius Esports, 평균 킬: 17.0
#   상대 팀: AS Esports, 평균 킬: 19.0
#   상대 팀: İstanbul Wildcats, 평균 킬: 19.0
#   상대 팀: Isurus, 평균 킬: 26.0
#   상대 팀: DRX, 평균 킬: 3.0
#   상대 팀: MAD Lions KOI, 평균 킬: 11.2
#   상대 팀: MGN Blue Esports, 평균 킬: 16.846153846153847
#   상대 팀: Rainbow Warriors, 평균 킬: 21.0
# 팀: Team Flash
#   상대 팀: MGN Vikings Esports, 평균 킬: 13.0
#   상대 팀: CERBERUS Esports, 평균 킬: 10.5
#   상대 팀: GAM Esports, 평균 킬: 14.176470588235293
#   상대 팀: Team Whales, 평균 킬: 12.263157894736842
#   상대 팀: , 평균 킬: 14.2
#   상대 팀: SBTC Esports, 평균 킬: 12.8
#   상대 팀: Team Secret, 평균 킬: 12.266666666666667
#   상대 팀: MGN Blue Esports, 평균 킬: 16.25
#   상대 팀: Rainbow Warriors, 평균 킬: 17.75
# 팀: GAM Esports
#   상대 팀: CERBERUS Esports, 평균 킬: 16.444444444444443
#   상대 팀: Team Secret, 평균 킬: 18.0
#   상대 팀: Team Flash, 평균 킬: 16.941176470588236
#   상대 팀: MGN Vikings Esports, 평균 킬: 17.733333333333334
#   상대 팀: Team Whales, 평균 킬: 19.083333333333332
#   상대 팀: , 평균 킬: 21.25
#   상대 팀: SBTC Esports, 평균 킬: 16.71875
#   상대 팀: AS Esports, 평균 킬: 19.25
#   상대 팀: Genius Esports, 평균 킬: 23.0
#   상대 팀: Top Esports, 평균 킬: 13.5
#   상대 팀: Rogue, 평균 킬: 7.0
#   상대 팀: DRX, 평균 킬: 6.5
#   상대 팀: MGN Blue Esports, 평균 킬: 18.285714285714285
#   상대 팀: Golden Guardians, 평균 킬: 6.5
#   상대 팀: Movistar R7, 평균 킬: 18.6
#   상대 팀: LOUD, 평균 킬: 15.5
#   상대 팀: Gen.G, 평균 킬: 5.0
#   상대 팀: Fnatic, 평균 킬: 7.0
#   상대 팀: Team Liquid, 평균 킬: 13.333333333333334
#   상대 팀: Dplus KIA, 평균 킬: 3.0
#   상대 팀: Rainbow Warriors, 평균 킬: 26.5
# 팀: CERBERUS Esports
#   상대 팀: GAM Esports, 평균 킬: 12.481481481481481
#   상대 팀: Team Flash, 평균 킬: 14.555555555555555
#   상대 팀: , 평균 킬: 17.2
#   상대 팀: SBTC Esports, 평균 킬: 15.052631578947368
#   상대 팀: Team Secret, 평균 킬: 14.096774193548388
#   상대 팀: MGN Vikings Esports, 평균 킬: 10.958333333333334
#   상대 팀: Team Whales, 평균 킬: 14.419354838709678
#   상대 팀: AS Esports, 평균 킬: 18.75
#   상대 팀: Genius Esports, 평균 킬: 18.8
#   상대 팀: MGN Blue Esports, 평균 킬: 17.75
#   상대 팀: Rainbow Warriors, 평균 킬: 15.5
# 팀: West Point Esports
#   상대 팀: CTBC Flying Oyster, 평균 킬: 6.9
#   상대 팀: PSG Talon, 평균 킬: 4.7
#   상대 팀: Deep Cross Gaming, 평균 킬: 11.166666666666666
#   상대 팀: Dewish Team, 평균 킬: 15.0
#   상대 팀: Beyond Gaming, 평균 킬: 9.0
#   상대 팀: Impunity, 평균 킬: 13.375
#   상대 팀: HELL PIGS, 평균 킬: 12.0
#   상대 팀: J Team, 평균 킬: 7.75
#   상대 팀: Frank Esports, 평균 킬: 5.9
# 팀: Team Aze
#   상대 팀: DetonatioN FocusMe, 평균 킬: 9.0
#   상대 팀: T1, 평균 킬: 6.0
#   상대 팀: MGN Vikings Esports, 평균 킬: 6.5
# 팀: DetonatioN FocusMe
#   상대 팀: Team Aze, 평균 킬: 16.5
#   상대 팀: MGN Vikings Esports, 평균 킬: 24.5
#   상대 팀: T1, 평균 킬: 8.5
#   상대 팀: LOUD, 평균 킬: 13.0
#   상대 팀: Fnatic, 평균 킬: 12.0
#   상대 팀: Chiefs Esports Club, 평균 킬: 19.0
#   상대 팀: Beyond Gaming, 평균 킬: 26.0
#   상대 팀: Evil Geniuses, 평균 킬: 13.0
#   상대 팀: Royal Never Give Up, 평균 킬: 8.0
#   상대 팀: PSG Talon, 평균 킬: 14.0
#   상대 팀: CTBC Flying Oyster, 평균 킬: 7.0
#   상대 팀: Team BDS, 평균 킬: 4.5
#   상대 팀: J Team, 평균 킬: 13.6
#   상대 팀: Frank Esports, 평균 킬: 8.0
#   상대 팀: Deep Cross Gaming, 평균 킬: 14.0
# 팀: ORDER
#   상대 팀: G2 Esports, 평균 킬: 7.5
#   상대 팀: Evil Geniuses, 평균 킬: 4.5
# 팀: İstanbul Wildcats
#   상대 팀: Royal Never Give Up, 평균 킬: 9.5
#   상대 팀: RED Canids, 평균 킬: 10.0
#   상대 팀: PSG Talon, 평균 킬: 10.5
#   상대 팀: MAD Lions KOI, 평균 킬: 11.0
#   상대 팀: MGN Vikings Esports, 평균 킬: 14.0
#   상대 팀: DRX, 평균 킬: 10.0
#   상대 팀: Isurus, 평균 킬: 11.0
# 팀: Royal Never Give Up
#   상대 팀: İstanbul Wildcats, 평균 킬: 24.0
#   상대 팀: PSG Talon, 평균 킬: 18.2
#   상대 팀: RED Canids, 평균 킬: 26.666666666666668
#   상대 팀: Evil Geniuses, 평균 킬: 23.2
#   상대 팀: G2 Esports, 평균 킬: 14.5
#   상대 팀: T1, 평균 킬: 13.4
#   상대 팀: MGN Vikings Esports, 평균 킬: 13.333333333333334
#   상대 팀: EDward Gaming, 평균 킬: 10.8
#   상대 팀: LNG Esports, 평균 킬: 9.2
#   상대 팀: DRX, 평균 킬: 9.0
#   상대 팀: MAD Lions KOI, 평균 킬: 21.0
#   상대 팀: Isurus, 평균 킬: 33.0
#   상대 팀: DetonatioN FocusMe, 평균 킬: 16.5
#   상대 팀: Gen.G, 평균 킬: 7.333333333333333
#   상대 팀: CTBC Flying Oyster, 평균 킬: 21.5
#   상대 팀: 100 Thieves, 평균 킬: 16.5
# 팀: AS Esports
#   상대 팀: Team Whales, 평균 킬: 12.4
#   상대 팀: GAM Esports, 평균 킬: 9.5
#   상대 팀: SBTC Esports, 평균 킬: 11.75
#   상대 팀: CERBERUS Esports, 평균 킬: 11.75
#   상대 팀: Team Secret, 평균 킬: 9.0
#   상대 팀: Genius Esports, 평균 킬: 23.0
#   상대 팀: MGN Vikings Esports, 평균 킬: 7.25
# 팀: Genius Esports
#   상대 팀: Team Secret, 평균 킬: 11.4
#   상대 팀: SBTC Esports, 평균 킬: 11.6
#   상대 팀: Team Whales, 평균 킬: 14.5
#   상대 팀: GAM Esports, 평균 킬: 10.5
#   상대 팀: MGN Vikings Esports, 평균 킬: 11.8
#   상대 팀: AS Esports, 평균 킬: 16.0
#   상대 팀: CERBERUS Esports, 평균 킬: 11.0
# 팀: EDward Gaming
#   상대 팀: Royal Never Give Up, 평균 킬: 9.8
#   상대 팀: T1, 평균 킬: 7.0
#   상대 팀: Cloud9, 평균 킬: 17.0
#   상대 팀: Fnatic, 평균 킬: 18.5
#   상대 팀: DRX, 평균 킬: 11.8
#   상대 팀: LNG Esports, 평균 킬: 8.0
#   상대 팀: Weibo Gaming, 평균 킬: 10.0
# 팀: Ninjas in Pyjamas
#   상대 팀: LNG Esports, 평균 킬: 12.75
# 팀: LNG Esports
#   상대 팀: Ninjas in Pyjamas, 평균 킬: 15.75
#   상대 팀: Royal Never Give Up, 평균 킬: 7.8
#   상대 팀: EDward Gaming, 평균 킬: 13.25
#   상대 팀: Fnatic, 평균 킬: 22.0
#   상대 팀: Cloud9, 평균 킬: 14.0
#   상대 팀: JD Gaming, 평균 킬: 9.0
#   상대 팀: KT Rolster, 평균 킬: 10.666666666666666
#   상대 팀: T1, 평균 킬: 2.6666666666666665
# 팀: Isurus
#   상대 팀: MAD Lions KOI, 평균 킬: 12.0
#   상대 팀: MGN Vikings Esports, 평균 킬: 10.0
#   상대 팀: Royal Never Give Up, 평균 킬: 6.0
#   상대 팀: DRX, 평균 킬: 5.0
#   상대 팀: İstanbul Wildcats, 평균 킬: 20.0
# 팀: Chiefs Esports Club
#   상대 팀: Fnatic, 평균 킬: 6.0
#   상대 팀: DetonatioN FocusMe, 평균 킬: 10.0
#   상대 팀: Evil Geniuses, 평균 킬: 6.0
#   상대 팀: Beyond Gaming, 평균 킬: 10.6
#   상대 팀: LOUD, 평균 킬: 18.0
#   상대 팀: CTBC Flying Oyster, 평균 킬: 9.666666666666666
#   상대 팀: Deep Cross Gaming, 평균 킬: 9.0
#   상대 팀: Frank Esports, 평균 킬: 9.25
# 팀: JD Gaming
#   상대 팀: Evil Geniuses, 평균 킬: 20.5
#   상대 팀: Dplus KIA, 평균 킬: 17.333333333333332
#   상대 팀: G2 Esports, 평균 킬: 16.0
#   상대 팀: Rogue, 평균 킬: 12.333333333333334
#   상대 팀: T1, 평균 킬: 12.846153846153847
#   상대 팀: Golden Guardians, 평균 킬: 16.0
#   상대 팀: Bilibili Gaming, 평균 킬: 17.25
#   상대 팀: Team BDS, 평균 킬: 14.0
#   상대 팀: LNG Esports, 평균 킬: 10.333333333333334
#   상대 팀: KT Rolster, 평균 킬: 12.5
# 팀: Top Esports
#   상대 팀: GAM Esports, 평균 킬: 20.0
#   상대 팀: DRX, 평균 킬: 8.5
#   상대 팀: Rogue, 평균 킬: 12.5
#   상대 팀: Weibo Gaming, 평균 킬: 9.0
# 팀: Fluxo
#   상대 팀: Los Grandes, 평균 킬: 10.333333333333334
#   상대 팀: Liberty, 평균 킬: 15.0
#   상대 팀: LOUD, 평균 킬: 13.666666666666666
#   상대 팀: KaBuM! Esports, 평균 킬: 15.166666666666666
#   상대 팀: paiN Gaming, 평균 킬: 10.666666666666666
#   상대 팀: FURIA, 평균 킬: 11.222222222222221
#   상대 팀: Vivo Keyd Stars, 평균 킬: 15.090909090909092
#   상대 팀: INTZ, 평균 킬: 13.833333333333334
#   상대 팀: RED Canids, 평균 킬: 13.833333333333334
# 팀: Team Heretics
#   상대 팀: Astralis, 평균 킬: 17.666666666666668
#   상대 팀: Team Vitality, 평균 킬: 13.5
#   상대 팀: SK Gaming, 평균 킬: 14.8
#   상대 팀: Rogue, 평균 킬: 16.428571428571427
#   상대 팀: G2 Esports, 평균 킬: 6.8
#   상대 팀: Fnatic, 평균 킬: 13.0
#   상대 팀: GiantX, 평균 킬: 14.8
#   상대 팀: MAD Lions KOI, 평균 킬: 16.333333333333332
#   상대 팀: Team BDS, 평균 킬: 12.166666666666666
#   상대 팀: Karmine Corp, 평균 킬: 16.0
# 팀: Vivo Keyd Stars
#   상대 팀: FURIA, 평균 킬: 16.0
#   상대 팀: paiN Gaming, 평균 킬: 12.545454545454545
#   상대 팀: Los Grandes, 평균 킬: 19.333333333333332
#   상대 팀: RED Canids, 평균 킬: 9.666666666666666
#   상대 팀: Liberty, 평균 킬: 21.333333333333332
#   상대 팀: LOUD, 평균 킬: 12.833333333333334
#   상대 팀: Fluxo, 평균 킬: 14.545454545454545
#   상대 팀: KaBuM! Esports, 평균 킬: 14.833333333333334
#   상대 팀: INTZ, 평균 킬: 17.9
# 팀: MGN Blue Esports
#   상대 팀: GAM Esports, 평균 킬: 13.357142857142858
#   상대 팀: Team Secret, 평균 킬: 10.071428571428571
#   상대 팀: CERBERUS Esports, 평균 킬: 11.916666666666666
#   상대 팀: SBTC Esports, 평균 킬: 11.0
#   상대 팀: MGN Vikings Esports, 평균 킬: 9.076923076923077
#   상대 팀: Team Flash, 평균 킬: 12.1875
#   상대 팀: Team Whales, 평균 킬: 10.545454545454545
#   상대 팀: Rainbow Warriors, 평균 킬: 23.25
# 팀: Team Bliss
#   상대 팀: Impunity, 평균 킬: 13.666666666666666
#   상대 팀: Deep Cross Gaming, 평균 킬: 7.666666666666667
#   상대 팀: Beyond Gaming, 평균 킬: 5.666666666666667
#   상대 팀: CTBC Flying Oyster, 평균 킬: 8.0
# 팀: Bilibili Gaming
#   상대 팀: Movistar R7, 평균 킬: 23.5
#   상대 팀: Golden Guardians, 평균 킬: 20.0
#   상대 팀: Cloud9, 평균 킬: 19.0
#   상대 팀: JD Gaming, 평균 킬: 8.625
#   상대 팀: G2 Esports, 평균 킬: 18.285714285714285
#   상대 팀: Gen.G, 평균 킬: 15.75
#   상대 팀: T1, 평균 킬: 11.666666666666666
#   상대 팀: KT Rolster, 평균 킬: 20.0
#   상대 팀: Fnatic, 평균 킬: 15.0
#   상대 팀: Weibo Gaming, 평균 킬: 13.0
# 팀: Movistar R7
#   상대 팀: Bilibili Gaming, 평균 킬: 6.5
#   상대 팀: GAM Esports, 평균 킬: 13.4
#   상대 팀: Golden Guardians, 평균 킬: 3.5
#   상대 팀: PSG Talon, 평균 킬: 6.5
# 팀: OKSavingsBank BRION
#   상대 팀: Nongshim RedForce, 평균 킬: 7.7272727272727275
#   상대 팀: Kwangdong Freecs, 평균 킬: 12.818181818181818
#   상대 팀: Dplus KIA, 평균 킬: 6.2
#   상대 팀: T1, 평균 킬: 8.333333333333334
#   상대 팀: BNK FEARX, 평균 킬: 7.777777777777778
#   상대 팀: Hanwha Life Esports, 평균 킬: 8.11111111111111
#   상대 팀: Gen.G, 평균 킬: 10.75
#   상대 팀: DRX, 평균 킬: 9.090909090909092
#   상대 팀: KT Rolster, 평균 킬: 7.75
# 팀: Weibo Gaming
#   상대 팀: Top Esports, 평균 킬: 15.2
#   상대 팀: EDward Gaming, 평균 킬: 15.25
#   상대 팀: NRG Kia, 평균 킬: 15.0
#   상대 팀: G2 Esports, 평균 킬: 23.0
#   상대 팀: KT Rolster, 평균 킬: 11.0
#   상대 팀: MAD Lions KOI, 평균 킬: 19.0
#   상대 팀: Fnatic, 평균 킬: 13.0
#   상대 팀: Bilibili Gaming, 평균 킬: 13.2
#   상대 팀: T1, 평균 킬: 3.6666666666666665
# 팀: PSG Talon Academy
#   상대 팀: Impunity, 평균 킬: 20.833333333333332
#   상대 팀: , 평균 킬: 12.0
# 팀: Karmine Corp
#   상대 팀: Fnatic, 평균 킬: 10.0
#   상대 팀: G2 Esports, 평균 킬: 12.5
#   상대 팀: MAD Lions KOI, 평균 킬: 14.0
#   상대 팀: GiantX, 평균 킬: 11.5
#   상대 팀: Team Vitality, 평균 킬: 12.0
#   상대 팀: Team Heretics, 평균 킬: 6.5
#   상대 팀: Rogue, 평균 킬: 8.0
#   상대 팀: SK Gaming, 평균 킬: 17.0
#   상대 팀: Team BDS, 평균 킬: 8.0
# 팀: Rainbow Warriors
#   상대 팀: MGN Blue Esports, 평균 킬: 17.75
#   상대 팀: Team Whales, 평균 킬: 13.75
#   상대 팀: CERBERUS Esports, 평균 킬: 9.0
#   상대 팀: Team Secret, 평균 킬: 11.5
#   상대 팀: Team Flash, 평균 킬: 5.0
#   상대 팀: GAM Esports, 평균 킬: 10.5
#   상대 팀: MGN Vikings Esports, 평균 킬: 9.5
# 팀: Shopify Rebellion
#   상대 팀: FlyQuest, 평균 킬: 15.5
#   상대 팀: Team Liquid, 평균 킬: 3.5
#   상대 팀: Immortals, 평균 킬: 14.0
#   상대 팀: Cloud9, 평균 킬: 17.5
#   상대 팀: Dignitas, 평균 킬: 10.5
#   상대 팀: NRG Kia, 평균 킬: 18.5
#   상대 팀: 100 Thieves, 평균 킬: 10.5
# 팀: V3 Esports
#   상대 팀: Beyond Gaming, 평균 킬: 7.0
#   상대 팀: Ground Zero Gaming, 평균 킬: 8.0
# 팀: Ground Zero Gaming
#   상대 팀: Deep Cross Gaming, 평균 킬: 10.75
#   상대 팀: V3 Esports, 평균 킬: 20.5
# 팀: Antic Esports
#   상대 팀: Frank Esports, 평균 킬: 5.5
#   상대 팀: J Team, 평균 킬: 11.5
# 팀: Fukuoka SoftBank HAWKS gaming
#   상대 팀: PSG Talon, 평균 킬: 8.875
#   상대 팀: Deep Cross Gaming, 평균 킬: 17.8
#   상대 팀: Frank Esports, 평균 킬: 19.2
#   상대 팀: CTBC Flying Oyster, 평균 킬: 19.333333333333332

# %%
train_ft.shape,test_ft.shape
# Out:
# ((9913, 114), (2324, 114))

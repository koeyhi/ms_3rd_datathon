# %%
import pandas as pd

df = pd.read_csv("LoLesports_data/2014_LoL_esports_match_data_from_OraclesElixir.csv")
df = df[df["datacompleteness"] == "complete"].drop(columns=["url", "datacompleteness"])

# %%
df.head(50)
# Out:
#          gameid  league  year   split  playoffs                 date  game  \
# 0      TRLH3/33  EU LCS  2014  Spring         0  2014-01-14 17:52:02     1
# 1      TRLH3/33  EU LCS  2014  Spring         0  2014-01-14 17:52:02     1
# 2      TRLH3/33  EU LCS  2014  Spring         0  2014-01-14 17:52:02     1
# 3      TRLH3/33  EU LCS  2014  Spring         0  2014-01-14 17:52:02     1
# 4      TRLH3/33  EU LCS  2014  Spring         0  2014-01-14 17:52:02     1
# 5      TRLH3/33  EU LCS  2014  Spring         0  2014-01-14 17:52:02     1
# 6      TRLH3/33  EU LCS  2014  Spring         0  2014-01-14 17:52:02     1
# 7      TRLH3/33  EU LCS  2014  Spring         0  2014-01-14 17:52:02     1
# 8      TRLH3/33  EU LCS  2014  Spring         0  2014-01-14 17:52:02     1
# 9      TRLH3/33  EU LCS  2014  Spring         0  2014-01-14 17:52:02     1
# 10     TRLH3/33  EU LCS  2014  Spring         0  2014-01-14 17:52:02     1
# ...
